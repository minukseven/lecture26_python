# %%
class Circle:
    pi = 3.14
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return self.radius ** 2 * Circle.pi

c = Circle(2.5)
print(c.area())
# Out:
# 19.625

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height
    
rec = Rectangle(2.1, 3.4)
print(rec.area())
# Out:
# 7.14

# %%
class Account:
    def __init__(self):
        self.balance = 0
    def deposit(self, amount):
        self.balance += amount
    def withdraw(self, amount):
        self.balance -= amount

a1 = Account()
a1.deposit(100)
print(a1.balance)
# Out:
# 100

# %%
class Account:
    def __init__(self):
        self.__balance = 0
    def deposit(self, amount):
        self.__balance += amount
    def withdraw(self, amount):
        self.__balance -= amount
    def get_balance(self):
        return self.__balance
    
a2 = Account()
a2.deposit(50)
print(a2.get_balance())
# Out:
# 50

# %%
# 매직 매서드 연습
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __str__(self):
        return f'{self.name}({self.age}살)'
    def __eq__(self, other):
        if self.name == other.name and self.age == other.age:
            return True
        return False

p1 = Person('홍길동', 15)
print(p1)

p2 = Person('홍길동', 15)

if p1 == p2:
    print('같은 사람입니다.')
else:
    print('다른 사람입니다.')
# Out:
# 홍길동(15살)
# 같은 사람입니다.

# %%
# 학습 내용 되돌아보기 (1)

class TV:
    def __init__(self, size):  # self 매개변수 추가!
        self.size = size

class Car:
    def __init__(self, color):
        self.color = color  # this → self 로 변경!

class TV:
    cnt_products = 0  # 클래스 속성 선언

    def __init__(self, size):   # ← 첫 번째 빈칸
        self.size = size
        TV.cnt_products += 1    # ← 두 번째 빈칸

mine = TV(60)
print(TV.cnt_products)  # 출력: 1
# Out:
# 1

# %%
# 학습 내용 되돌아보기(2)

class Integer:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):        # ← 첫 번째 빈칸
        return self.value + other.value

    def __sub__(self, other):        # ← 두 번째 빈칸
        return self.value - other.value

a = Integer(5)
b = Integer(3)

print(a + b)

print(a - b)
# Out:
# 8
# 2

# %%
# 학습 내용 되돌아보기(3)

class Student:
    def info(self):
        print('대학: ' + self.univ + ' 이름: ' + self.name)


s = Student()
s.name = '이성실'
s.univ = '한국대학교'


s.info()
# Out:
# 대학: 한국대학교 이름: 이성실

# %%
# 학습 내용 되돌아보기(4)

class Student:
    def __init__(self, name, dept, mid, final):
        self.name = name
        self.dept = dept
        self.mid = mid
        self.final = final

    def __str__(self):
        return '학과: ' + self.dept + ', 이름: ' + self.name + ', 중간: ' + str(self.mid) + ', 기말: ' + str(self.final)

    def grade(self):
        avg = (self.mid + self.final) / 2
        if avg >= 90:
            return 'A'
        elif avg >= 80:
            return 'B'
        elif avg >= 70:
            return 'C'
        elif avg >= 60:
            return 'D'
        else:
            return 'F'


s = Student('김경철', '기계학과', 89, 90)


print(s)


print('학점:', s.grade())
# Out:
# 학과: 기계학과, 이름: 김경철, 중간: 89, 기말: 90
# 학점: B

# %%
# 학습 내용 되돌아보기(5)

class Car:
    def __init__(self, brand, year, color):
        self.brand = brand
        self.year = year
        self.color = color

    def __str__(self):
        return '자동차 회사: ' + self.brand + ', 년식: ' + str(self.year) + ', 색상: ' + self.color

    def __eq__(self, other):
        return self.brand == other.brand and self.year == other.year and self.color == other.color

# 객체 생성
mycar = Car('현대', 2020, '검정')
yourcar = Car('기아', 2021, '백색')

print(mycar)
print(yourcar)
print(mycar == yourcar)
# Out:
# 자동차 회사: 현대, 년식: 2020, 색상: 검정
# 자동차 회사: 기아, 년식: 2021, 색상: 백색
# False
